# %%
import pandas as pd
import lxml
import html5lib
import bs4

# %%
# Get filename and path from user
print('Filepath and name')
print('Example: /Users/rg/Dropbox/00 Privat/Audio/30_playlists_xml_etc/20181210.html')
filename =  input('please enter here: ')
# Out:
# Filepath and name
# Example: /Users/rg/Dropbox/00 Privat/Audio/30_playlists_xml_etc/20181210.html
# please enter here:  20190111_banging_techno.html

# %%
# Extract path, title and extension from filename
file_path = filename.split('.')[0]
file_extension = filename.split('.')[-1]
file_name = file_path.split('/')[-1]

# %%
# Read html
l = pd.read_html(filename, header=0)

# Create a list of dataframes from the tables in the html file
df = l[0]

# %%
df.head()
# Out:
#    Num.  Color                                     Title  \
# 0     1    NaN               Love Someone Else Mood Edit
# 1     2    NaN            Love Someone Else Original Mix
# 2     3    NaN                           Vanishing Point
# 3     4    NaN  Bombastik (Original Mix) [TraxCrate.com]
# 4     5    NaN                   Hidden T (Original Mix)
#
#                            Artist   Time    BPM  Track  \
# 0  Nicole Moudaber, Skunk Anansie  07:11  124.0    NaN
# 1  Nicole Moudaber, Skunk Anansie  07:11  124.0    NaN
# 2                     Setaoc Mass  05:45  131.0    3.0
# 3                          John P  06:03  128.0    NaN
# 4              Enrico Sangiuliano  07:49  126.0    NaN
#
#                    Release          Label   Genre  ... Release Date Bitrate  \
# 0                      NaN            NaN  Techno  ...          NaN  320000
# 1                      NaN            NaN  Techno  ...          NaN  320000
# 2             Reframe E.P.      SK_Eleven  Techno  ...   2017/01/01  320000
# 3            TraxCrate.com  TraxCrate.com  Techno  ...   2018/01/01  320000
# 4  www.electronicfresh.com       Drumcode  Techno  ...   2018/06/01  320000
#
#   Comment2 Play Count Last Played Import Date          Start Time Duration  \
# 0      NaN          1  2019/01/11  2019/01/11  2019/1/11 11:19:15    10:14
# 1      NaN          1  2019/01/11  2019/01/11  2019/1/11 11:22:59    05:43
# 2      NaN          1  2019/01/11  2019/01/11  2019/1/11 11:30:23    07:48
# 3      NaN          1  2019/01/11  2019/01/11  2019/1/11 11:36:05    05:39
# 4      NaN          1  2019/01/11  2019/01/11  2019/1/11 11:40:19    06:42
#
#      Deck Played Public
# 0  Deck A           yes
# 1  Deck B           yes
# 2  Deck A           yes
# 3  Deck B           yes
# 4  Deck A           yes
#
# [5 rows x 29 columns]

# %%
# Remove duplicates
df = df.drop_duplicates(subset='Title')

# Subset for export
df_export = df[['Title', 'Artist']]

# %%
df_export
# Out:
#                                       Title                          Artist
# 0               Love Someone Else Mood Edit  Nicole Moudaber, Skunk Anansie
# 1            Love Someone Else Original Mix  Nicole Moudaber, Skunk Anansie
# 2                           Vanishing Point                     Setaoc Mass
# 3  Bombastik (Original Mix) [TraxCrate.com]                          John P
# 4                   Hidden T (Original Mix)              Enrico Sangiuliano
# 5            Visionary (Beico & Mt93 Remix)                   Bruno Aguirre
# 6                 Star (Drunken Kong Remix)                    Fatima Hajji
# 7               Interstellar (Original Mix)                     Victor Ruiz
# 8       For an Endless Night (Original Mix)                Alan Fitzpatrick
# 9     For An Endless Night (Jel Ford Remix)                Alan Fitzpatrick

# %%
df_export.to_csv(f'{file_name}.csv', index=False)
